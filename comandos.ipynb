# %%
# !git config --global user.email "20b3010069@untels.edu.pe"
# !git config --global user.name "JairoDaniel-17"

# %%
# !git clone https://github.com/Jairodaniel-17/googlecolab-semana03.git
# Out:
# Cloning into 'googlecolab-semana03'...
